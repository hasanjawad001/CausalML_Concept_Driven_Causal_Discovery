# %%
import pickle
import numpy as np
from scipy import stats
## stats.ttest_ind, stats.ttest_ind_from_stats(mean1, std1, nobs1, mean2, std2, nobs2, equal_var=True, alternative='two-sided')
import pandas as pd

# %%
def which_is_better(mean1, std1, nobs1, mean2, std2, nobs2, alpha_one_tail=0.025):
    # Test whether mean(M1) > mean(M2) using Welch's t-test
    # at default alpha = 0.025 significance level for the one tail test
    #
    # M1 - relevant
    # M2 - irrelevant
    #
    # Note that stats.ttest_ind return the two-tailed p-value
    #
    # Null hypothesis: mean(M1) <= mean(M2)
    # Alternative: mean(M1) > mean(M2) 
    #
    # REJECT if pvalue/2 < alpha
    
    # tstat, pvalue = stats.ttest_ind(M1_values, M2_values, equal_var = False)
    tstat, pvalue = stats.ttest_ind_from_stats(mean1, std1, nobs1, mean2, std2, nobs2, equal_var = False)    
    print('tstat = ', tstat)
    print('pvalue = ', pvalue)
    if pvalue/2 < alpha_one_tail:
        if tstat < 0.0:
            print('Null rejected: more confident that mean(M1) < mean(M2)')
            return 0
        else:
            # you want to be here
            print('Null rejected: more confident that mean(M1) > mean(M2)')
            return 1-pvalue
        return True
    else:
        print('Cannot reject null: no confidence which one is better')
        return 0

# %%
list_dt_st = [('nonlinear', 'mlp')] ## [('nonlinear', 'mlp'), ('linear', 'mlp')]
list_n = [200, 1000] ## [200, 1000]
list_d = [10, 20] ## [10, 20]
list_s0_factor = [1, 4] ## [1, 4]
list_gt = ['ER', 'SF'] ## ['ER', 'SF']
list_should_std = [False, True] ## [False, True]
n_trials = 50 ## 10

# %%
d_result = {}

for dt, st in list_dt_st:
    for n in list_n:
        for d in list_d:
            for s0_factor in list_s0_factor:
                for gt in list_gt:
                    for should_std in list_should_std:
                        with open('datasets/d_result_' + str(n) + '_' + str(d) + '_' + str(s0_factor) + '_' + str(gt) + '_' + str(should_std) + '.pickle', 'rb') as handle:
                            d_result_local = pickle.load(handle)
                            d_result.update(d_result_local)

# %%
for dt, st in list_dt_st:
    for n in list_n:
        for d in list_d:
            for s0_factor in list_s0_factor:
                for gt in list_gt:
                    for should_std in list_should_std:
                        
                        fdr, tpr, fpr, shd, nnz = [], [], [], [], []
                        for tn in range(n_trials):
                            key = (n, d, s0_factor, gt, should_std, tn, 'nCon')
                            value = d_result[key]
                            if value[0] != '-':
                                fdr.append(value[0])
                            if value[1] != '-':
                                tpr.append(value[1])
                            if value[2] != '-':
                                fpr.append(value[2])
                            if value[3] != '-':
                                shd.append(value[3])
                            if value[4] != '-':
                                nnz.append(value[4])
                        nvalid = len(tpr)
                        assert nvalid == len(fdr) == len(fpr) == len(shd) == len(nnz)
                            
                        fdr2, tpr2, fpr2, shd2, nnz2 = [], [], [], [], []
                        for tn in range(n_trials):
                            key = (n, d, s0_factor, gt, should_std, tn, 'nReg')
                            value = d_result[key]
                            if value[0] != '-':
                                fdr2.append(value[0])
                            if value[1] != '-':
                                tpr2.append(value[1])
                            if value[2] != '-':
                                fpr2.append(value[2])
                            if value[3] != '-':
                                shd2.append(value[3])
                            if value[4] != '-':
                                nnz2.append(value[4])      
                        nvalid2 = len(tpr2)
                        assert nvalid2 == len(fdr2) == len(fpr2) == len(shd2) == len(nnz2)
                                
                          
                        # print("{} ==> {:0.2f} ± {:0.2f} vs {:0.2f} ± {:0.2f}".format(key[:-2], np.mean(fdr), np.std(fdr), np.mean(fdr2), np.std(fdr2)))
                        # which_is_better(np.mean(fdr), np.std(fdr), nvalid, np.mean(fdr2), np.std(fdr2), nvalid2)                                                
                        print("{} ==> {:0.2f} ± {:0.2f} vs {:0.2f} ± {:0.2f}".format(key[:-2], np.mean(tpr), np.std(tpr), np.mean(tpr2), np.std(tpr2)))
                        which_is_better(np.mean(tpr), np.std(tpr), nvalid, np.mean(tpr2), np.std(tpr2), nvalid2)
                        # print("{} ==> {:0.2f} ± {:0.2f} vs {:0.2f} ± {:0.2f}".format(key[:-2], np.mean(fpr), np.std(fpr), np.mean(fpr2), np.std(fpr2)))
                        # which_is_better(np.mean(fpr), np.std(fpr), nvalid, np.mean(fpr2), np.std(fpr2), nvalid2)                        
                        print("{} ==> {:0.2f} ± {:0.2f} vs {:0.2f} ± {:0.2f}".format(key[:-2], np.mean(shd), np.std(shd), np.mean(shd2), np.std(shd2)))  
                        which_is_better(np.mean(shd), np.std(shd), nvalid, np.mean(shd2), np.std(shd2), nvalid2)                    
                        print("{} ==> {:0.2f} ± {:0.2f} vs {:0.2f} ± {:0.2f}".format(key[:-2], np.mean(nnz), np.std(nnz), np.mean(nnz2), np.std(nnz2)))   
                        which_is_better(np.mean(nnz), np.std(nnz), nvalid, np.mean(nnz2), np.std(nnz2), nvalid2)   
                        print(key[:-2], nvalid, nvalid2)
                        print()
                        print()
                        
# (200, 10, 1, 'ER', False) ==> 0.15 ± 0.15 vs 0.16 ± 0.12
# tstat =  -0.2848351864492735
# pvalue =  0.776830141185211
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'ER', False) ==> 182.87 ± 55.39 vs 180.61 ± 51.47
# tstat =  0.1662774266392898
# pvalue =  0.8685006980254553
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'ER', False) ==> 183.87 ± 54.73 vs 183.55 ± 50.56
# (200, 10, 1, 'ER', False) 31 31
# Out:
# (200, 10, 1, 'ER', False) ==> 0.15 ± 0.15 vs 0.16 ± 0.12
# tstat =  -0.2848351864492735
# pvalue =  0.776830141185211
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'ER', False) ==> 182.87 ± 55.39 vs 180.61 ± 51.47
# tstat =  0.1662774266392898
# pvalue =  0.8685006980254553
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'ER', False) ==> 183.87 ± 54.73 vs 183.55 ± 50.56
# tstat =  0.024104493259018825
# pvalue =  0.9808497457646737
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'ER', False) 31 31
#
#
# (200, 10, 1, 'ER', True) ==> 0.53 ± 0.17 vs 0.54 ± 0.14
# tstat =  -0.28440189373051866
# pvalue =  0.7768100617781318
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'ER', True) ==> 143.40 ± 51.91 vs 147.66 ± 54.13
# tstat =  -0.37156898802540717
# pvalue =  0.7111666774847947
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'ER', True) ==> 151.89 ± 52.84 vs 162.51 ± 59.73
# tstat =  -0.870105977193183
# pvalue =  0.3868367741278529
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'ER', True) 45 41
#
#
# (200, 10, 1, 'SF', False) ==> 0.10 ± 0.12 vs 0.10 ± 0.09
# tstat =  0.13783677263201718
# pvalue =  0.8908893006739367
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'SF', False) ==> 152.40 ± 43.05 vs 173.53 ± 48.45
# tstat =  -1.8473353254266371
# pvalue =  0.06947139432079807
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'SF', False) ==> 152.33 ± 44.03 vs 173.82 ± 49.69
# tstat =  -1.8345081524504536
# pvalue =  0.07137782673871025
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'SF', False) 30 34
#
#
# (200, 10, 1, 'SF', True) ==> 0.18 ± 0.14 vs 0.23 ± 0.13
# tstat =  -1.7426466121396045
# pvalue =  0.08529182986767159
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'SF', True) ==> 153.96 ± 46.77 vs 156.41 ± 45.41
# tstat =  -0.2409555106998467
# pvalue =  0.8102207593044674
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'SF', True) ==> 145.13 ± 43.33 vs 156.30 ± 44.60
# tstat =  -1.1482781465215839
# pvalue =  0.25444344067601826
# Cannot reject null: no confidence which one is better
# (200, 10, 1, 'SF', True) 46 37
#
#
# (200, 10, 4, 'ER', False) ==> 0.44 ± 0.17 vs 0.40 ± 0.15
# tstat =  0.8856096420369265
# pvalue =  0.3796052552348118
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'ER', False) ==> 110.45 ± 45.56 vs 129.15 ± 43.10
# tstat =  -1.613394294410642
# pvalue =  0.11237665694121118
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'ER', False) ==> 171.36 ± 58.94 vs 179.15 ± 46.84
# tstat =  -0.5656925603144847
# pvalue =  0.5738234017340087
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'ER', False) 33 26
#
#
# (200, 10, 4, 'ER', True) ==> 0.57 ± 0.10 vs 0.55 ± 0.07
# tstat =  0.8089635685125254
# pvalue =  0.4210859786140211
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'ER', True) ==> 89.84 ± 26.88 vs 99.77 ± 25.93
# tstat =  -1.7638525868346686
# pvalue =  0.08131267537311081
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'ER', True) ==> 150.50 ± 38.23 vs 158.89 ± 37.57
# tstat =  -1.0379041326709573
# pvalue =  0.3022250113444571
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'ER', True) 44 44
#
#
# (200, 10, 4, 'SF', False) ==> 0.21 ± 0.13 vs 0.22 ± 0.15
# tstat =  -0.3842984610789904
# pvalue =  0.7021317151945362
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'SF', False) ==> 149.36 ± 43.19 vs 159.06 ± 48.52
# tstat =  -0.8322961176447878
# pvalue =  0.4085639913126915
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'SF', False) ==> 168.29 ± 46.88 vs 175.18 ± 46.53
# tstat =  -0.5779237834589959
# pvalue =  0.5655691428845409
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'SF', False) 28 34
#
#
# (200, 10, 4, 'SF', True) ==> 0.33 ± 0.15 vs 0.38 ± 0.11
# tstat =  -1.579216228673704
# pvalue =  0.11806300036327093
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'SF', True) ==> 117.71 ± 30.53 vs 120.16 ± 28.26
# tstat =  -0.3852280134424989
# pvalue =  0.7010670399606447
# Cannot reject null: no confidence which one is better
# (200, 10, 4, 'SF', True) ==> 104.52 ± 37.55 vs 124.16 ± 35.24
# tstat =  -2.492885463217215
# pvalue =  0.014694860476469769
# Null rejected: more confident that mean(M1) < mean(M2)
# (200, 10, 4, 'SF', True) 48 38
#
#
# (200, 20, 1, 'ER', False) ==> 0.16 ± 0.11 vs 0.17 ± 0.09
# tstat =  -0.2953043762516196
# pvalue =  0.7689151857753462
# Cannot reject null: no confidence which one is better
# (200, 20, 1, 'ER', False) ==> 582.66 ± 87.50 vs 609.46 ± 97.83
# tstat =  -1.0662030513949403
# pvalue =  0.2914011285346806
# Cannot reject null: no confidence which one is better
# (200, 20, 1, 'ER', False) ==> 579.97 ± 86.06 vs 609.85 ± 94.30
# tstat =  -1.2225711959975785
# pvalue =  0.22712006426292197
# Cannot reject null: no confidence which one is better
# (200, 20, 1, 'ER', False) 29 26
#
#
# (200, 20, 1, 'ER', True) ==> 0.41 ± 0.13 vs 0.46 ± 0.08
# tstat =  -2.315603327752132
# pvalue =  0.023388988960949677
# Null rejected: more confident that mean(M1) < mean(M2)
# (200, 20, 1, 'ER', True) ==> 593.78 ± 109.97 vs 605.38 ± 108.03
# tstat =  -0.49629378642329086
# pvalue =  0.6209716030752375
# Cannot reject null: no confidence which one is better
# (200, 20, 1, 'ER', True) ==> 591.98 ± 99.75 vs 624.36 ± 106.97
# tstat =  -1.457482402531296
# pvalue =  0.14873932694899308
# Cannot reject null: no confidence which one is better
# (200, 20, 1, 'ER', True) 45 42
#
#
# (200, 20, 1, 'SF', False) ==> 0.13 ± 0.07 vs 0.16 ± 0.06
# tstat =  -1.8065960533270022
# pvalue =  0.07643022155997801
# Cannot reject null: no confidence which one is better
# (200, 20, 1, 'SF', False) ==> 417.41 ± 106.63 vs 479.93 ± 102.19
# tstat =  -2.254357044159939
# pvalue =  0.028268729936859475
# Null rejected: more confident that mean(M1) < mean(M2)
# (200, 20, 1, 'SF', False) ==> 418.93 ± 105.35 vs 485.40 ± 101.46
# tstat =  -2.4204431824554
# pvalue =  0.018903644511097537
# Null rejected: more confident that mean(M1) < mean(M2)
# (200, 20, 1, 'SF', False) 27 30
#
#
# (200, 20, 1, 'SF', True) ==> 0.18 ± 0.10 vs 0.21 ± 0.09
# tstat =  -1.6279793093558774
# pvalue =  0.1073372820395094
# Cannot reject null: no confidence which one is better
# (200, 20, 1, 'SF', True) ==> 678.16 ± 104.03 vs 694.48 ± 110.53
# tstat =  -0.6984650188086807
# pvalue =  0.48690164031933414
# Cannot reject null: no confidence which one is better
# (200, 20, 1, 'SF', True) ==> 658.98 ± 98.52 vs 692.65 ± 109.51
# tstat =  -1.4830550639493685
# pvalue =  0.1420362585484527
# Cannot reject null: no confidence which one is better
# (200, 20, 1, 'SF', True) 45 40
#
#
# (200, 20, 4, 'ER', False) ==> 0.35 ± 0.11 vs 0.35 ± 0.13
# tstat =  -0.29947530114598647
# pvalue =  0.7655935445488712
# Cannot reject null: no confidence which one is better
# (200, 20, 4, 'ER', False) ==> 543.78 ± 97.23 vs 551.00 ± 81.18
# tstat =  -0.3223794534720251
# pvalue =  0.748284280021106
# Cannot reject null: no confidence which one is better
# (200, 20, 4, 'ER', False) ==> 525.91 ± 83.67 vs 544.72 ± 63.52
# tstat =  -1.0130845034365619
# pvalue =  0.31524037328008975
# Cannot reject null: no confidence which one is better
# (200, 20, 4, 'ER', False) 32 32
#
#
# (200, 20, 4, 'ER', True) ==> 0.47 ± 0.08 vs 0.50 ± 0.06
# tstat =  -1.5080011484192597
# pvalue =  0.13510059017356632
# Cannot reject null: no confidence which one is better
# (200, 20, 4, 'ER', True) ==> 426.82 ± 84.44 vs 424.77 ± 82.93
# tstat =  0.11763790481983853
# pvalue =  0.906615967942375
# Cannot reject null: no confidence which one is better
# (200, 20, 4, 'ER', True) ==> 460.08 ± 93.18 vs 485.50 ± 95.32
# tstat =  -1.2976678090585398
# pvalue =  0.19773788013204374
# Cannot reject null: no confidence which one is better
# (200, 20, 4, 'ER', True) 49 44
#
#
# (200, 20, 4, 'SF', False) ==> 0.27 ± 0.12 vs 0.25 ± 0.08
# tstat =  0.8425335031591521
# pvalue =  0.40564357500923376
# Cannot reject null: no confidence which one is better
# (200, 20, 4, 'SF', False) ==> 496.85 ± 82.17 vs 520.92 ± 80.47
# tstat =  -0.9765137426042428
# pvalue =  0.3346410279580405
# Cannot reject null: no confidence which one is better
# (200, 20, 4, 'SF', False) ==> 542.15 ± 109.61 vs 534.58 ± 73.16
# tstat =  0.26364059156450187
# pvalue =  0.7937433795329033
# Cannot reject null: no confidence which one is better
# (200, 20, 4, 'SF', False) 20 24
#
#
# (200, 20, 4, 'SF', True) ==> 0.26 ± 0.13 vs 0.32 ± 0.12
# tstat =  -2.2800860460906547
# pvalue =  0.02484100554140219
# Null rejected: more confident that mean(M1) < mean(M2)
# (200, 20, 4, 'SF', True) ==> 553.20 ± 109.93 vs 552.94 ± 100.17
# tstat =  0.012366272119661216
# pvalue =  0.990159350500261
# Cannot reject null: no confidence which one is better
# (200, 20, 4, 'SF', True) ==> 488.34 ± 87.04 vs 541.55 ± 79.98
# tstat =  -3.137727505090073
# pvalue =  0.002268045708517022
# Null rejected: more confident that mean(M1) < mean(M2)
# (200, 20, 4, 'SF', True) 50 47
#
#
# (1000, 10, 1, 'ER', False) ==> 0.14 ± 0.14 vs 0.15 ± 0.11
# tstat =  -0.23399179720881533
# pvalue =  0.8157498525947036
# Cannot reject null: no confidence which one is better
# (1000, 10, 1, 'ER', False) ==> 154.94 ± 46.31 vs 162.50 ± 49.29
# tstat =  -0.6707228825970879
# pvalue =  0.5046097232256468
# Cannot reject null: no confidence which one is better
# (1000, 10, 1, 'ER', False) ==> 150.85 ± 43.81 vs 158.03 ± 48.46
# tstat =  -0.659679004335559
# pvalue =  0.511624791922618
# Cannot reject null: no confidence which one is better
# (1000, 10, 1, 'ER', False) 34 38
#
#
# (1000, 10, 1, 'ER', True) ==> 0.34 ± 0.15 vs 0.43 ± 0.13
# tstat =  -2.9873067642926046
# pvalue =  0.003579879102807254
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 10, 1, 'ER', True) ==> 61.24 ± 28.21 vs 70.79 ± 28.28
# tstat =  -1.6735276973364706
# pvalue =  0.09748525384984348
# Cannot reject null: no confidence which one is better
# (1000, 10, 1, 'ER', True) ==> 51.70 ± 25.53 vs 72.94 ± 29.16
# tstat =  -3.8297108400053888
# pvalue =  0.00023240730157779628
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 10, 1, 'ER', True) 50 48
#
#
# (1000, 10, 1, 'SF', False) ==> 0.02 ± 0.05 vs 0.02 ± 0.04
# tstat =  0.38312794332178585
# pvalue =  0.703302673398855
# Cannot reject null: no confidence which one is better
# (1000, 10, 1, 'SF', False) ==> 138.96 ± 34.03 vs 166.62 ± 38.44
# tstat =  -3.002480657394684
# pvalue =  0.003907675200900455
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 10, 1, 'SF', False) ==> 131.61 ± 32.01 vs 159.29 ± 36.83
# tstat =  -3.1656420477171014
# pvalue =  0.0024348410779013595
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 10, 1, 'SF', False) 28 34
#
#
# (1000, 10, 1, 'SF', True) ==> 0.13 ± 0.10 vs 0.15 ± 0.10
# tstat =  -0.6354874990743998
# pvalue =  0.5266661036334199
# Cannot reject null: no confidence which one is better
# (1000, 10, 1, 'SF', True) ==> 73.96 ± 32.48 vs 82.47 ± 31.29
# tstat =  -1.313918628540187
# pvalue =  0.19203959436963652
# Cannot reject null: no confidence which one is better
# (1000, 10, 1, 'SF', True) ==> 53.00 ± 27.50 vs 71.32 ± 26.80
# tstat =  -3.322032353391816
# pvalue =  0.0012701232066569662
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 10, 1, 'SF', True) 50 47
#
#
# (1000, 10, 4, 'ER', False) ==> 0.18 ± 0.09 vs 0.17 ± 0.05
# tstat =  0.4941194839069427
# pvalue =  0.6228050715282905
# Cannot reject null: no confidence which one is better
# (1000, 10, 4, 'ER', False) ==> 145.33 ± 31.68 vs 155.28 ± 36.64
# tstat =  -1.3474178299805997
# pvalue =  0.18154449498599215
# Cannot reject null: no confidence which one is better
# (1000, 10, 4, 'ER', False) ==> 94.77 ± 36.89 vs 104.12 ± 31.70
# tstat =  -1.2603299494587563
# pvalue =  0.21111907440684846
# Cannot reject null: no confidence which one is better
# (1000, 10, 4, 'ER', False) 43 43
#
#
# (1000, 10, 4, 'ER', True) ==> 0.34 ± 0.09 vs 0.40 ± 0.07
# tstat =  -3.67764003300183
# pvalue =  0.0004058572886423836
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 10, 4, 'ER', True) ==> 113.65 ± 30.98 vs 106.62 ± 27.77
# tstat =  1.1525851690220419
# pvalue =  0.25210527063715465
# Cannot reject null: no confidence which one is better
# (1000, 10, 4, 'ER', True) ==> 72.90 ± 18.82 vs 98.07 ± 22.25
# tstat =  -5.8710262796855215
# pvalue =  7.845228697105108e-08
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 10, 4, 'ER', True) 48 45
#
#
# (1000, 10, 4, 'SF', False) ==> 0.09 ± 0.10 vs 0.10 ± 0.08
# tstat =  -0.22824789330706763
# pvalue =  0.8200599935547896
# Cannot reject null: no confidence which one is better
# (1000, 10, 4, 'SF', False) ==> 161.17 ± 45.00 vs 166.13 ± 38.31
# tstat =  -0.5328422956338295
# pvalue =  0.5956629257275924
# Cannot reject null: no confidence which one is better
# (1000, 10, 4, 'SF', False) ==> 132.93 ± 42.20 vs 137.61 ± 37.04
# tstat =  -0.5277856337972973
# pvalue =  0.5991476205860056
# Cannot reject null: no confidence which one is better
# (1000, 10, 4, 'SF', False) 42 38
#
#
# (1000, 10, 4, 'SF', True) ==> 0.12 ± 0.10 vs 0.18 ± 0.12
# tstat =  -2.704809679150604
# pvalue =  0.00826498462522902
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 10, 4, 'SF', True) ==> 111.40 ± 32.78 vs 110.22 ± 32.31
# tstat =  0.17618331713955349
# pvalue =  0.8605362729363313
# Cannot reject null: no confidence which one is better
# (1000, 10, 4, 'SF', True) ==> 27.58 ± 15.45 vs 47.96 ± 22.64
# tstat =  -5.067567040433529
# pvalue =  2.7209338534753913e-06
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 10, 4, 'SF', True) 50 45
#
#
# (1000, 20, 1, 'ER', False) ==> 0.17 ± 0.09 vs 0.15 ± 0.09
# tstat =  0.7201572458812787
# pvalue =  0.47774329164765916
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'ER', False) ==> 633.06 ± 110.57 vs 655.76 ± 131.62
# tstat =  -0.6464897890324002
# pvalue =  0.5223364444656565
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'ER', False) ==> 632.19 ± 115.34 vs 654.22 ± 132.29
# tstat =  -0.6099430576852487
# pvalue =  0.5461364981596476
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'ER', False) 16 37
#
#
# (1000, 20, 1, 'ER', True) ==> 0.38 ± 0.11 vs 0.40 ± 0.10
# tstat =  -0.5579243579181176
# pvalue =  0.5782233990738982
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'ER', True) ==> 264.28 ± 85.20 vs 278.41 ± 81.97
# tstat =  -0.82812498505157
# pvalue =  0.4097017102182734
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'ER', True) ==> 253.66 ± 82.55 vs 281.11 ± 81.57
# tstat =  -1.637607660094371
# pvalue =  0.10486453727806774
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'ER', True) 50 46
#
#
# (1000, 20, 1, 'SF', False) ==> 0.10 ± 0.06 vs 0.10 ± 0.06
# tstat =  -0.10153388102494111
# pvalue =  0.9196099906308858
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'SF', False) ==> 475.65 ± 140.26 vs 530.21 ± 144.18
# tstat =  -1.3133324776997022
# pvalue =  0.1962409827372869
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'SF', False) ==> 467.20 ± 136.63 vs 524.11 ± 143.94
# tstat =  -1.3911590293998592
# pvalue =  0.1714444058792741
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'SF', False) 20 28
#
#
# (1000, 20, 1, 'SF', True) ==> 0.11 ± 0.08 vs 0.13 ± 0.08
# tstat =  -0.7852721989352252
# pvalue =  0.43430713029069623
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'SF', True) ==> 434.06 ± 109.89 vs 424.25 ± 105.69
# tstat =  0.44350061540789326
# pvalue =  0.6584374763025176
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'SF', True) ==> 389.64 ± 103.82 vs 399.44 ± 100.84
# tstat =  -0.4665463656141019
# pvalue =  0.6419182892142125
# Cannot reject null: no confidence which one is better
# (1000, 20, 1, 'SF', True) 47 48
#
#
# (1000, 20, 4, 'ER', False) ==> 0.42 ± 0.12 vs 0.43 ± 0.13
# tstat =  -0.2477109703925185
# pvalue =  0.8051271640059519
# Cannot reject null: no confidence which one is better
# (1000, 20, 4, 'ER', False) ==> 517.85 ± 99.27 vs 526.17 ± 104.49
# tstat =  -0.3368190881599089
# pvalue =  0.7373220524047088
# Cannot reject null: no confidence which one is better
# (1000, 20, 4, 'ER', False) ==> 550.64 ± 102.51 vs 580.17 ± 109.11
# tstat =  -1.1509254254733907
# pvalue =  0.25391564069539374
# Cannot reject null: no confidence which one is better
# (1000, 20, 4, 'ER', False) 33 35
#
#
# (1000, 20, 4, 'ER', True) ==> 0.41 ± 0.08 vs 0.42 ± 0.06
# tstat =  -1.3366487942925327
# pvalue =  0.1847814723443209
# Cannot reject null: no confidence which one is better
# (1000, 20, 4, 'ER', True) ==> 274.46 ± 59.15 vs 291.31 ± 50.81
# tstat =  -1.4697192007302224
# pvalue =  0.14512702665243568
# Cannot reject null: no confidence which one is better
# (1000, 20, 4, 'ER', True) ==> 236.00 ± 44.78 vs 280.50 ± 42.42
# tstat =  -4.88589055638282
# pvalue =  4.5382671509901e-06
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 20, 4, 'ER', True) 50 42
#
#
# (1000, 20, 4, 'SF', False) ==> 0.20 ± 0.11 vs 0.20 ± 0.11
# tstat =  0.10420236365862391
# pvalue =  0.9174285456653628
# Cannot reject null: no confidence which one is better
# (1000, 20, 4, 'SF', False) ==> 575.20 ± 109.84 vs 607.44 ± 124.59
# tstat =  -0.9915257324196589
# pvalue =  0.32621386584590073
# Cannot reject null: no confidence which one is better
# (1000, 20, 4, 'SF', False) ==> 562.28 ± 108.06 vs 595.89 ± 126.35
# tstat =  -1.0330867970215414
# pvalue =  0.30656407482007986
# Cannot reject null: no confidence which one is better
# (1000, 20, 4, 'SF', False) 25 27
#
#
# (1000, 20, 4, 'SF', True) ==> 0.07 ± 0.05 vs 0.12 ± 0.07
# tstat =  -3.310695478304034
# pvalue =  0.0013536460119630246
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 20, 4, 'SF', True) ==> 360.80 ± 81.40 vs 363.31 ± 75.05
# tstat =  -0.1583524687815629
# pvalue =  0.8745164147508169
# Cannot reject null: no confidence which one is better
# (1000, 20, 4, 'SF', True) ==> 134.59 ± 58.14 vs 180.71 ± 57.67
# tstat =  -3.9220432710435187
# pvalue =  0.0001658660455713725
# Null rejected: more confident that mean(M1) < mean(M2)
# (1000, 20, 4, 'SF', True) 49 48
